# %%
import ultralytics
from ultralytics import YOLO
import torch
# torch.cuda.set_device(0) # Set to your desired GPU number
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.11 🚀 Python-3.9.18 torch-2.2.0 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Setup complete ✅ (16 CPUs, 31.9 GB RAM, 1664.7/1862.3 GB disk)

# %%
# load model
# model = YOLO('yolov8n.yaml')  # build a new model from YAML
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
# model = YOLO('yolov8n.yaml').load('yolov8n.pt')  # build from YAML and transfer weights

# %%
# train model
results = model.train(data='C:/Users/Alex/Desktop/SENECA/Semester 9/BDC800_Capstone/Capstone Project/DeepRadiology/dataset/setup.yaml', epochs=1, imgsz=2880)
print('training complete')

# %%
# validate
# model = YOLO('yolov8n.pt')  # load an official model
model = YOLO('path/to/best.pt')  # load a custom model

metrics = results.val()  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category

# %%
# predict
# model = YOLO('yolov8n.pt')  # load an official model
model = YOLO('path/to/best.pt')  # load a custom model
results = model('C:/Users/Alex/Desktop/SENECA/Semester 9/BDC800_Capstone/Capstone Project/DeepRadiology/dataset/images/test/0b1f7b86b0ddb459fb779c6d473d96ad.tiff')  # predict on an image
